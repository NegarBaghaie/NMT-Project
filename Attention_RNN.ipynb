# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '20'

import re
import unicodedata
import time
import io

import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Layer, GRU, Dense, Embedding, Activation, Bidirectional
from keras.models import Model
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from keras.metrics import Metric
from keras.optimizers import Adam

import matplotlib.ticker as ticker
from transformers import BertTokenizer, AutoTokenizer
from parsivar import Normalizer
import tensorflow_text as tf_text 
from keras.layers import TextVectorization

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


device = tf.config.experimental.list_physical_devices('GPU')[0]
print(device)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
en_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
fa_tokenizer = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')
# Out:
# /home/alireza/miniconda3/envs/tf15/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def create_dataset(file_path, num_examples=None):
    en_fa = []
    cnt = 0
    fa_normalizer = Normalizer()
    with open(file_path, 'r') as file:
        for line in file.readlines():
            if num_examples is not None and cnt >= num_examples: break
            line = line.split('\t')[:2]
            en = line[0]
            fa = fa_normalizer.normalize(line[1])
            fa = re.sub('\u200c', ' ', fa)
            en_fa.append([en, fa])
            cnt += 1
            if cnt % 100 == 0:
                print(f'\rRead {cnt:>5}', end='')

    print('\nRead', cnt)
    return zip(*en_fa)


def sort_dataset(source, target):
    xy = sorted(zip(source, target), key=lambda x: (len(x[0].split(' ')), len(x[1].split(' ')))) 
    x = [x[0] for x in xy]
    y = [y[1] for y in xy]
    return x, y

# %%
NUM_SAMPLES = 1_000_000
FILE_PATH = './Data/combined.txt'
src_lang, targ_lang = create_dataset(FILE_PATH, NUM_SAMPLES)
# Out:
# Read 994200
# Read 994267

# %%
src_train, src_val, targ_train, targ_val = train_test_split(src_lang, targ_lang, test_size=0.2, shuffle=True, random_state=123)
src_train, targ_train = sort_dataset(src_train, targ_train)
src_val, targ_val = sort_dataset(src_val, targ_val)
print('Source Train examples:', len(src_train))
print('Source Validation examples:', len(src_val))
# Out:
# Source Train examples: 795413
# Source Validation examples: 198854

# %%
i = -1
print('Training Example (English)')
print(src_val[i])

print('Training Example (Persian)')
print(targ_val[i])
# Out:
# Training Example (English)
# He also admitted that you had some interest in a mill or mills we did not press him on this, being most upset at this information which was news to us that necessitated your riding about alone, or attended by a ruffian who, Captain Butler assures us, is a murderer.
# Training Example (Persian)
# او همچنین اعتراف کرد که شما به یک آسیاب یا آسیاب علاقه داشتید ، ما او را در این مورد تحت فشار قرار ندادیم ، زیرا از این اطلاعات که برای ما خبری بود که باعث می شد شما به تنهایی سوار شوید ، یا با حضور یک رفیق که ، کاپیتان باتلر به ما اطمینان می دهد ، بسیار ناراحت بودیم . ، یک قاتل است .

# %%
def en_vectorization(text):
    text = [x.decode('utf-8') for x in text.numpy()]
    return en_tokenizer(text, padding=True, return_tensors='tf')['input_ids']

def fa_vectorization(text):
    text = [x.decode('utf-8') for x in text.numpy()]
    return fa_tokenizer(text, padding=True, return_tensors='tf')['input_ids']

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 128
STEPS_PER_EPOCH = len(src_train) // BATCH_SIZE
BUFFER_SIZE = 1000

def preprocess(src, targ):
    src = tf.py_function(func=en_vectorization, inp=[src], Tout=tf.TensorSpec(shape=(None, None), dtype=tf.int32))
    src = tf.cast(src, tf.int32)
    targ = tf.py_function(func=fa_vectorization, inp=[targ], Tout=tf.TensorSpec(shape=(None, None), dtype=tf.int32))
    targ = tf.cast(targ, tf.int32)
    return src, targ

train_ds = tf.data.Dataset.from_tensor_slices((src_train, targ_train))
train_ds = train_ds.batch(BATCH_SIZE, num_parallel_calls=AUTOTUNE, drop_remainder=True)
train_ds = train_ds.map(preprocess,
                       num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache()
train_ds = train_ds.shuffle(STEPS_PER_EPOCH)
train_ds = train_ds.prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((src_val, targ_val))
test_ds = test_ds.batch(BATCH_SIZE, num_parallel_calls=AUTOTUNE, drop_remainder=True)
test_ds = test_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.prefetch(AUTOTUNE)

# %%
for example_train_source, example_train_target in train_ds.skip(0).take(20):
    print('Example Train Source:', example_train_source.shape)
    print('Example Train Target:', example_train_target.shape)
    print()
# Out:
# Example Train Source: (128, 28)
# Example Train Target: (128, 29)
#
# Example Train Source: (128, 11)
# Example Train Target: (128, 8)
#
# Example Train Source: (128, 17)
# Example Train Target: (128, 10)
#
# Example Train Source: (128, 20)
# Example Train Target: (128, 17)
#
# Example Train Source: (128, 28)
# Example Train Target: (128, 29)
#
# Example Train Source: (128, 33)
# Example Train Target: (128, 32)
#
# Example Train Source: (128, 18)
# Example Train Target: (128, 19)
#
# Example Train Source: (128, 15)
# Example Train Target: (128, 8)
#
# Example Train Source: (128, 25)
# Example Train Target: (128, 24)
#
# Example Train Source: (128, 14)
# Example Train Target: (128, 13)
#
# Example Train Source: (128, 28)
# Example Train Target: (128, 26)
#
# Example Train Source: (128, 39)
# Example Train Target: (128, 36)
#
# Example Train Source: (128, 10)
# Example Train Target: (128, 8)
#
# Example Train Source: (128, 17)
# Example Train Target: (128, 16)
#
# Example Train Source: (128, 10)
# Example Train Target: (128, 11)
#
# Example Train Source: (128, 15)
# Example Train Target: (128, 10)
#
# Example Train Source: (128, 12)
# Example Train Target: (128, 13)
#
# Example Train Source: (128, 17)
# Example Train Target: (128, 14)
#
# Example Train Source: (128, 23)
# Example Train Target: (128, 25)
#
# Example Train Source: (128, 20)
# Example Train Target: (128, 19)

# %%
for i in range(BATCH_SIZE):
    print('EXAMPLE English:', en_tokenizer.decode(example_train_source[i]))
    print('EXAMPLE Farsi:', fa_tokenizer.decode(example_train_target[i]))
    print()
# Out:
# EXAMPLE English: [CLS] stop him someone stop him. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] متوقفش کن کسی او را متوقف کند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and your mother called.'' thank you.'[SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و مادرت زنگ زد.'متشکرم.'[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] she probably just got it wrong. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] احتمالا تو رو با کس دیگه اشتباه گرفته[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] there's no occasion to pick'em ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] فرصتی برای انتخاب آن ها وجود ندارد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] something that happens to most people [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] چیزی که برای اکثر مردم اتفاق می افتد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] then subsided into the blazing grass. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] سپس در علف های سوزان فرو رفت.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] did he just tap out. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آیا او فقط به بیرون ضربه زد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he looked at me sourly enough [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] به اندازه کافی ترش به من نگاه کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] alyosha gazed at her in amazement. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آلیوشا با تعجب به او خیره شد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i need time to think. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] من به زمان نیاز دارم تا فکر کنم[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i feel the same way, [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] من احساس می کنم به همان شیوه ،[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] - i know, it is. - yeah. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. می دونم ، هست -. آره -[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] - precious little thing. - thank you. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. چه موجود کوچولوی عزیزی -. ممنونم -[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] sauron will suspect a trap. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] سائورون به یک تله مشکوک خواهد شد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] the, uh, blond is my ex - wife. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. آه ، مو طلایی ه زن سابقمه[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] how to make it seem unimportant? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] چگونه آن را بی اهمیت جلوه دهیم ؟[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] his eyes flash on raz's grave. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] چشمانش به قبر راز برق می زند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] we went, um, dancing the other night... [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] چون ، اون شب که داشتیم می رقصیدیم[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] harold nervously made small talk. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] هارولد با عصبانیت حرف های کوچک زد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and sunshine shoneout of my ass. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و نور آفتاب از تو باسنم میزد بیرون[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and the other officersin this castle. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. و بقیه ی فرمانده های این قلعه[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and i haven't changed my mind [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و نظرم نسبت به اینکه چه قلمروهایی به[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] looking at the card, dana thought [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] دانا با نگاه کردن به کارت فکر کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] get up, instantly, and tell him. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] فورا بلند شو و به او بگو.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] in fact, i've always hated this arm. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] درواقع ، از این بازوم همیشه بدم میومد[SEP][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] they are robbers, perhaps, he muttered. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] زمزمه کرد شاید آن ها دزد هستند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] holding a musket in his fist [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] یک تفنگ در مشت خود نگه داشته است[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] you know where to find me. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] تو می دانی که کجا پیدایم کنی.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] they know what you mean.. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آن ها منظور شما را می دانند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he tried to save us. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] او سعی کرد ما را نجات دهد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS]'decidedly not,'added the other members. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] سایر اعضا افزودند : « قطعا نه.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] through which the world is passing. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] در طوفان ها استوار و ثابت می مونه[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] they went about ship at once [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آن ها به یکباره در اطراف کشتی رفتند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] emma allowed her father to talk [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اما به پدرش اجازه داد تا صحبت کند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] well put the pieces together. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خوب قطعات را کنار هم قرار دهید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] any recurrences of his old patterns? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آیا تکرار الگوهای قدیمی او وجود دارد ؟[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] the bachelor then took his departure. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] لیسانس سپس خروج خود را آغاز کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i thought you liked his plan. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] فکر می کردم از نقشه اش خوشت میاد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] were built for style, not service [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] برای سبک ساخته شده اند ، نه خدمات[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] shark's laugh turns to a chuckle. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خنده کوسه تبدیل به خنده می شود.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i found her drivers license. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] گواهی نامه رانندگی او را پیدا کردم.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] the dead are everywhere, said morrel ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] مورل گفت : مردگان همه جا هستند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he spent six hours examining things [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] او شش ساعت را صرف بررسی مسائل کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] please hold. please hold. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] لطفا نگه دارید. لطفا نگه دارید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] your visa bill is huge! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] صورت حساب ویزای شما بسیار زیاد است![SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] once more he tried his luck [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] یک بار دیگر شانس خود را امتحان کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] theyll think then they think. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] فکر می کنند بعد فکر می کنند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] you know where to find him [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] شما می دانید کجا او را پیدا کنید[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] this is mr. gatsby, mr. buchanan. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] این آقای گتسبی است ، آقای بوکانان.[SEP][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] isabella and emma both write beautifully [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ایزابلا و اما هر دو زیبا می نویسند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] she began to sob, mastered it ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] او شروع به هق هق کردن کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and jasmine hall's a psychiatric unit. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. و جزمین هال یک واحد روانشناسانه هست[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] thought natasha : as one community [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ناتاشا فکر کرد : به عنوان یک جامعه[SEP][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] but before prince andrew could finish [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اما قبل از اینکه شاهزاده اندرو تمام کند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] go back, i suppose, aie aie! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] برگرد ، فکر کنم ، آی آی![SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] crazy bitch give me that. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] عوضی دیوانه آن را به من بده.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] ancient spells were carvedinto its foundations. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. طلسم های باستانی در بنیادش حک شدن[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] prince vasili became thoughtful and frowned. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] شاهزاده واسیلی متفکر شد و اخم کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] youre doing great, max. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] شما عالی کار می کنید ، حداکثر.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] next time you wanna do something... [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] دفعه ی بعدی که خواستی همچین کاری بکنی[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] wishing they was all like her! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] کاش همه آن ها مثل او بودند![SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] little party favors. check it out. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. هدیه های کوچیک مهمونی. اینو ببین[SEP][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] so there! a selfless good deed. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. پس بفرما! یه کار خوب ناخودخواهانه[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] well, go to it, i say. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خوب برو سراغش ، من می گویم.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and when you get it. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و هنگامی که آن را دریافت کردید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] mitya gazed at him in astonishment. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] میتیا با حیرت به او خیره شد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he told me all about it ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] او همه چیز را به من گفت.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] we don't take risks. all right? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ما ریسک پذیر نیستیم. خیلی خب ؟[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] his brain was moving very slowly ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] مغز او بسیار کند حرکت می کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] what happened in wahine? she asked. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] در واهین چه گذشت ؟ او پرسید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] toads had nosed their way in. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] وزغ ها به داخل دماغه کرده بودند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] it hid in books and food. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] در کتاب ها و غذا پنهان شد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] retweet this if you disagree. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اگر موافق نیستید این را ریتویت کنید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] well say, i got me comp'ny. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خوب بگو ، من شرکتم را گرفتم.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] but its not forever, you know. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اما برای همیشه نیست ، می دانید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] - nothing. - well, it's not nothing. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] هیچی - خب ، هیچی که نیست -[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] estha had, and when he did [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] استا داشت و وقتی این کار را کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he thinks his love is hopeless. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] او فکر می کند عشقش ناامید است.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] plantations don't amount to anything when [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] زمانی که مزارع به هیچ چیز نمی رسد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] my god, have mercy upon me! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خدای من ، به من رحم کن![SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] basketball orphan bullied by captain. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] یتیم بسکتبال مورد آزار و اذیت کاپیتان.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and i propose a plan which [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و من طرحی را پیشنهاد می کنم که[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] muley still sat regarding his meat. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] مولی هنوز در مورد گوشتش نشسته بود.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] maybe you do something different, you know? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ، شاید باید یه کار متفاوت کنیمیدونی ؟[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] people break up all the time. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] مردم همیشه از هم جدا می شوند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] after a few seconds you'll fall. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] بعد از چند ثانیه سقوط خواهید کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] we cant leave him behind. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ما نمی توانیم او را پشت سر بگذاریم[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] then he counted his steps, calculating [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] سپس قدم هایش را شمرد و حساب کرد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] men must sometimes have masculine conversation [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] مردان گاهی اوقات باید گفتگوی مردانه داشته باشند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] coming back hereafter everything that happened. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] برگردی اینجابا تموم اون اتفاقا که افتاده.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] typically, yeah, yeah. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] به طور معمول ، بله ، بله.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i felt it that time! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] من آن زمان آن را احساس کردم![SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] you're not even a low - life, scum - sucking maggot! [SEP]
# EXAMPLE Farsi: [CLS] تو یه کرم گه خور پست هم نیستی[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] he introduced them to the school. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آن ها را به مدرسه معرفی کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] that rope belt won't last long. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آن کمربند طناب زیاد دوام نخواهد آورد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] whose pale cheeks became slightly flushed [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] گونه های رنگ پریده اش کمی برافروخته شد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] was said and sharp ones, too. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] گفته شد و تند و تیز نیز.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS]'i heard you,'baby kochamma said. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] " بیبی کوچاما گفت : "" شنیدم ""."[SEP]
#
# EXAMPLE English: [CLS] both men entered monte cristo's carriage [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] هر دو نفر وارد کالسکه مونت کریستو شدند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] approached bolkonski with a slight bow. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] با تعظیم کمی به بولکونسکی نزدیک شد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] on'y got'bout forty dollars left. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اونا حدود چهل دلار باقی مانده است.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] nice flowers. bornagain bobby. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] گل های زیبا. تولد دوباره بابی.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] i am sure they were here [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] من مطمئن هستم که آن ها اینجا بودند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] yes, i've been looking for you. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] بله ، من به دنبال شما بودم.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and rembrandt moved him to ecstasy. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و رامبراند او را به وجد آورد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] but mrs. gould alone had appeared [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] اما خانم گولد به تنهایی ظاهر شده بود[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] her husband was adjusting his saber ; [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] شوهرش داشت سابرش را تنظیم می کرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] footsteps came rapidly down the corridor. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] ردپاها به سرعت از راهرو پایین آمدند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] are well documented in heaven. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] به خوبی در بهشت مستند شده اند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] four hundred girls live in fergussen. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] چهارصد دختر در فرگوسن زندگی می کنند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] with an army of northmen? loyal lad... [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] به جنوب لشگر کشی کرده ؟ پسرک وفادار[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] on twitter, amr quips : [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] عمرو در توییتر به طعنه می گوید :[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] the doctor tried to stop her. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] دکتر سعی کرد جلوی او را بگیرد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] unable to speak a christian tongue. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] نمی تواند به زبان مسیحی صحبت کند.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and avoid him until five o'clock [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] و تا ساعت پنج از او دوری کنید[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] who have directly made this exposure [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] که مستقیما این افشاگری را انجام داده اند[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] they were safe. for the moment. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] آن ها امن بودند برای یک لحظه.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] guys, dylan just called. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] بچه ها دیلن همین الان زنگ زد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] - that's it, just relax. - unh. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. خودشه ، آروم باش -. آه -[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] showed bright against the whitewashed brick [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] در برابر آجر سفید رنگ روشن نشان داد[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] and you're not supposedto be gossiping. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS]. و تو قرار نبود خبر چینی کنی[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS]'may i sit down, mr mancino? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] « می توانم بنشینم ، آقای مانچینو ؟[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] carmen was still smiling at renesmee. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] کارمن همچنان به رنسمی لبخند می زد.[SEP][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] very well, mademoiselle, i will explain [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] خیلی خوب ، مادموزل ، توضیح می دهم[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] that everyone will believe it.. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] که همه آن را باور کنند..[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] one day, in much good company [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] یک روز ، در یک شرکت بسیار خوب[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] you take lymphoma and tuberculosis. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] شما لنفوم و سل مصرف می کنید.[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
#
# EXAMPLE English: [CLS] no. no, it's not like that. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# EXAMPLE Farsi: [CLS] نه. نه ، اصلا همچین چیزی نیست[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]

# %%
SOURCE_VOCAB_SIZE = len(en_tokenizer.get_vocab())
TARGET_VOCAB_SIZE = len(fa_tokenizer.get_vocab())
ENCODER_UNITS = 64
DECODER_UNITS = 128
EMBD_DIM = 128
ATTENTION_UNITS = 10

# %%
class Encoder(Model):
    def __init__(self, rnn_units, vocab_size, embd_dim, batch_size):
      super(Encoder, self).__init__()
      self.rnn_units = rnn_units
      self.batch_size = batch_size
      self.embedding = Embedding(vocab_size, embd_dim)
      self.gru = Bidirectional(GRU(
            units=rnn_units,
            return_sequences=True,
            return_state=True
        ))
      self.initialize_state()

    def build(self):
        inputs = keras.layers.Input(shape=(None,))
        self.call(inputs)
        self.built = True
    
    def call(self, inputs, initial_state=None):
      if initial_state is not None:
          self._hidden = initial_state[0]
          self._backward_hidden = initial_state[1]
    
      x = self.embedding(inputs)
      sequences, h, bh = self.gru(x, initial_state=(self._hidden, self._backward_hidden))
    
      return sequences, (h, bh)
    
    
    def get_hidden_states(self):
      return self._hidden, self._backward_hidden
    
    def initialize_state(self):
      self._hidden = tf.zeros((self.batch_size, self.rnn_units))
      self._backward_hidden = tf.zeros((self.batch_size, self.rnn_units))
      return self.get_hidden_states()

# %%
encoder = Encoder(ENCODER_UNITS, SOURCE_VOCAB_SIZE, EMBD_DIM, BATCH_SIZE)
encoder.build()
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(output_sample.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(state_sample[0].shape))
encoder.summary()
# Out:
# Encoder output shape: (batch size, sequence length, units) (128, 20, 128)
# Encoder Hidden state shape: (batch size, units) (128, 64)
# Model: "encoder_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, None, 128)         3906816
#
#  bidirectional_5 (Bidirecti  [(128, None, 128),        74496
#  onal)                        (128, 64),
#                               (128, 64)]
#
# =================================================================
# Total params: 3981312 (15.19 MB)
# Trainable params: 3981312 (15.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class BahdanauAttention(Model):
  def __init__(self, units):
      super(BahdanauAttention, self).__init__()
      self.w1 = Dense(units)
      self.w2 = Dense(units)
      self.v = Dense(1)

  def call(self, sequences, s_prev):
      s_prev = tf.expand_dims(s_prev, 1)
      x = self.v(tf.nn.tanh(self.w1(sequences) + self.w2(s_prev)))
      attention_weights = tf.nn.softmax(x, axis=1)
      context = sequences * attention_weights
      context = tf.reduce_sum(context, axis=1)

      return context, attention_weights

# %%
attention = BahdanauAttention(ATTENTION_UNITS)
context, attention_weights = attention(output_sample, state_sample[0])

print("Attention result shape: (batch size, units) {}".format(context.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (128, 128)
# Attention weights shape: (batch_size, sequence_length, 1) (128, 20, 1)

# %%
class Decoder(Model):
    def __init__(self, rnn_units, attention_units, vocab_size, embd_dim):
        super(Decoder, self).__init__()
        self.rnn_units = rnn_units
        self.embedding = Embedding(vocab_size, embd_dim)
        self.gru = GRU(rnn_units, return_sequences=True, return_state=True)
        self.attention = BahdanauAttention(attention_units)
        self.fc = Dense(vocab_size)
        
    
    def call(self, inputs, sequences, s_prev):
      x = self.embedding(inputs)
    
      context, attention_weights = self.attention(sequences, s_prev)
      context = tf.expand_dims(context, 1)
      x = tf.concat([context, x], axis=-1)
      output, state = self.gru(x, s_prev)
      output = tf.reshape(output, (-1, output.shape[2]))
      output = self.fc(output)
    
      return output, state, attention_weights

# %%
decoder = Decoder(DECODER_UNITS, ATTENTION_UNITS, TARGET_VOCAB_SIZE, EMBD_DIM)
hidden = tf.concat([state_sample[0], state_sample[1]], axis=-1)
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      output_sample, hidden)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
decoder.summary()
# Out:
# Decoder output shape: (batch_size, vocab size) (128, 25001)
# Model: "decoder_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_17 (Embedding)    multiple                  3200128
#
#  gru_17 (GRU)                multiple                  148224
#
#  bahdanau_attention_13 (Bah  multiple                  2591
#  danauAttention)
#
#  dense_53 (Dense)            multiple                  3225129
#
# =================================================================
# Total params: 6576072 (25.09 MB)
# Trainable params: 6576072 (25.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
encoder = Encoder(ENCODER_UNITS, SOURCE_VOCAB_SIZE, EMBD_DIM, BATCH_SIZE)
decoder = Decoder(DECODER_UNITS, ATTENTION_UNITS, TARGET_VOCAB_SIZE, EMBD_DIM)

# %%
loss_object = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.optimizers.Adam()

class MaskedAccuracy(Metric):
    def __init__(self, name='masked_accuracy', **kwargs):
        super(MaskedAccuracy, self).__init__(name=name, **kwargs)

        self.total = self.add_weight(name='total', 
                                     shape=(), 
                                     dtype='float32', 
                                     initializer='zeros')
        
        self.count = self.add_weight(name='count', 
                                     shape=(), 
                                     dtype='float32', 
                                     initializer='zeros')


    def update_state(self, y_true, pred, sample_weights=None):
        # pred = [B, dec_seq_len, target_vocab_size]
        # y_true = [B, dec_seq_len]
        y_pred = tf.argmax(pred, axis=-1)
        y_pred = tf.cast(y_pred, y_true.dtype)
        mask = tf.logical_not(tf.equal(y_true, fa_tokenizer.pad_token_id))

        match = tf.equal(y_pred, y_true)
        match = tf.logical_and(match, mask)

        match = tf.cast(match, tf.float32)
        mask = tf.cast(mask, tf.float32)

        self.total.assign_add(tf.reduce_sum(match))
        self.count.assign_add(tf.reduce_sum(mask))


    def result(self):
        return self.total / self.count if self.count != 0 else 0

    def reset_state(self):
        self.total.assign(0.0)
        self.count.assign(0.0)
        
def loss_func(real, pred):
    # Make a mask that is 1 everywhere there is not a padding, and 0 for paddings
    mask = tf.math.logical_not(tf.math.equal(real, fa_tokenizer.pad_token_id))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

# %%
training_accuracy = MaskedAccuracy(name='train_acc')
test_accuracy = MaskedAccuracy(name='valid_acc')

# %%
def get_scheduler(d_model, warmup_steps=4000):
    def get_learning_rate(step):
        step = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step)
        arg2 = step * tf.math.pow(warmup_steps * 1.0, -1.5)

        return tf.math.rsqrt(d_model * 1.0) * tf.minimum(arg1, arg2)

    return get_learning_rate

# %%
EPOCHS = 30
scheduler = get_scheduler(EMBD_DIM, warmup_steps=int(0.10 * STEPS_PER_EPOCH * EPOCHS))
optimizer = Adam(beta_1=0.9, beta_2=0.98, epsilon=1e-9)

train_acc = MaskedAccuracy(name='train_acc')
valid_acc = MaskedAccuracy(name='valid_acc')

# %%
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(np.arange(STEPS_PER_EPOCH * EPOCHS), scheduler(np.arange(STEPS_PER_EPOCH * EPOCHS)));
ax.grid();
ax.set_title('Learning rate per step');
ax.set_xlabel('step')
ax.set_ylabel('learning_rate');

# %%
print('Loading cache...')
for i, (x, y) in enumerate(train_ds): 
    print(f'\r{i:>5}', end='')
print()
for i, (x, y) in enumerate(test_ds): 
    print(f'\r{i:>5}', end='')
print()
# Out:
# Loading cache...
#  6213
#  1552

# %%
inp_signature = tf.TensorSpec(shape=(None, None), dtype=tf.int32)
targ_signature = tf.TensorSpec(shape=(None, None), dtype=tf.int32)
hidden_signature = [tf.TensorSpec(shape=(BATCH_SIZE, ENCODER_UNITS), dtype=tf.float32)]

@tf.function(reduce_retracing=True)
def train_step(inp, targ, hidden):
    loss = 0.0
    with tf.GradientTape() as tape:
        enc_output, (enc_h, enc_bh) = encoder(inp, hidden)
        dec_hidden = tf.concat([enc_h, enc_bh], axis=-1)
        dec_inputs = tf.expand_dims([fa_tokenizer.cls_token_id] * BATCH_SIZE, 1)

        for t in range(1, tf.shape(targ)[1]):
            dec_outputs, dec_hidden, _ = decoder(dec_inputs, enc_output, dec_hidden, training=True)
            computed_loss = loss_func(targ[:, t], dec_outputs)
            loss = loss + computed_loss
            dec_inputs = tf.expand_dims(targ[:, t], 1)
            training_accuracy.update_state(targ[:, t], dec_outputs)


    batch_loss = loss / tf.cast(tf.shape(targ)[1], tf.float32)
    variables = encoder.trainable_variables + decoder.trainable_variables
    grads = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(grads, variables))
    return batch_loss

# %%
@tf.function(reduce_retracing=True)
def test_step(inp, targ, hidden):
    loss = 0.0
    enc_output, (enc_h, enc_bh) = encoder(inp, hidden, training=False)
    dec_hidden = tf.concat([enc_h, enc_bh], axis=-1)
    dec_inputs = tf.expand_dims([fa_tokenizer.cls_token_id] * BATCH_SIZE, 1)

    for t in range(1, tf.shape(targ)[1]):
        dec_outputs, dec_hidden, _ = decoder(dec_inputs, enc_output, dec_hidden, training=False)
        computed_loss = loss_func(targ[:, t], dec_outputs)
        loss = loss + computed_loss
        dec_inputs = tf.expand_dims(targ[:, t], 1)
        test_accuracy.update_state(targ[:, t], dec_outputs)

    batch_loss = loss / tf.cast(tf.shape(targ)[1], tf.float32)

    return batch_loss

# %%
train_writer = tf.summary.create_file_writer(logdir='./logs/RNN/train')
test_writer = tf.summary.create_file_writer(logdir='./logs/RNN/test')

# %%
train_mean_losses = []
train_accs = []
valid_mean_losses = []
valid_accs = []
total_steps = 0

for epoch in range(EPOCHS):
    training_accuracy.reset_state()
    test_accuracy.reset_state()
    train_mean_loss = 0
    valid_mean_loss = 0
    hidden = encoder.initialize_state()
    start = time.time()
    
    print(f"epoch {epoch + 1}:\n")
    for step, (source, target) in enumerate(train_ds):
        optimizer.learning_rate = scheduler(total_steps)
        loss = train_step(source, target, hidden)
        train_acc = training_accuracy.result()
        train_mean_loss = train_mean_loss + (1 / (step + 1)) * (loss - train_mean_loss)
        end = time.time()

        print(f'\r{int(end - start):>4} sec | Step {step + 1:>5}\tloss: {train_mean_loss:>4.3f} \taccuracy: {train_acc:>4.3f}', end='')
        
        with train_writer.as_default():
            tf.summary.scalar('Loss_Per_Step', train_mean_loss, step=total_steps)
            tf.summary.scalar('Accuracy_Per_Step', train_acc, step=total_steps)
        total_steps += 1
            
    print()
    train_mean_losses.append(train_mean_loss)
    train_accs.append(train_acc)

    with train_writer.as_default():
        tf.summary.scalar('Loss_Per_Epoch', train_mean_loss, step=epoch)
        tf.summary.scalar('Accuracy_Per_Epoch', train_acc, step=epoch)
    
    for step, (source, target) in enumerate(test_ds):
        loss = test_step(source, target, hidden)
        test_acc = test_accuracy.result()
        valid_mean_loss = valid_mean_loss + (1 / (step + 1)) * (loss - valid_mean_loss)
        end = time.time()

        print(f'\r{int(end - start):>4} sec | Step {step + 1:>5}\tloss: {valid_mean_loss:>4.3f} \taccuracy: {test_acc:>4.3f}', end='')

    
    valid_mean_losses.append(valid_mean_loss)
    valid_accs.append(test_acc)

    with test_writer.as_default():
        tf.summary.scalar('Loss_Per_Epoch', valid_mean_loss, step=epoch)
        tf.summary.scalar('Accuracy_Per_Epoch', test_acc, step=epoch)


    encoder.save_weights(f'./Checkpoints/RNN/Encoder/{epoch}.h5')
    decoder.save_weights(f'./Checkpoints/RNN/Decoder/{epoch}.h5')
    print('\n')
# Out:
# epoch 1:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1719267924.812598  112292 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 2060" frequency: 1560 num_cores: 30 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12020" } environment { key: "cudnn" value: "8904" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 3145728 shared_memory_size_per_multiprocessor: 65536 memory_size: 5021040640 bandwidth: 264048000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719267926.361543  112473 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#    6 sec | Step     1	loss: 7.944 	accuracy: 0.000
# W0000 00:00:1719267929.126881  112292 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 2060" frequency: 1560 num_cores: 30 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12020" } environment { key: "cudnn" value: "8904" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 3145728 shared_memory_size_per_multiprocessor: 65536 memory_size: 5021040640 bandwidth: 264048000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 1575 sec | Step  6214	loss: 4.174 	accuracy: 0.105
# 1862 sec | Step  1553	loss: 3.294 	accuracy: 0.180
#
# epoch 2:
#
# 1494 sec | Step  6214	loss: 2.997 	accuracy: 0.247
# 1779 sec | Step  1553	loss: 2.674 	accuracy: 0.308
#
# epoch 3:
#
# 1495 sec | Step  6214	loss: 2.388 	accuracy: 0.369
# 1780 sec | Step  1553	loss: 2.098 	accuracy: 0.422
#
# epoch 4:
#
# 1495 sec | Step  6214	loss: 1.898 	accuracy: 0.459
# 1780 sec | Step  1553	loss: 1.724 	accuracy: 0.490
#
# epoch 5:
#
# 1495 sec | Step  6214	loss: 1.616 	accuracy: 0.515
# 1780 sec | Step  1553	loss: 1.547 	accuracy: 0.529
#
# epoch 6:
#
# 1496 sec | Step  6214	loss: 1.456 	accuracy: 0.549
# 1781 sec | Step  1553	loss: 1.456 	accuracy: 0.549
#
# epoch 7:
#
# 1500 sec | Step  6214	loss: 1.357 	accuracy: 0.572
# 1785 sec | Step  1553	loss: 1.371 	accuracy: 0.566
#
# epoch 8:
#
# 1496 sec | Step  6214	loss: 1.288 	accuracy: 0.589
# 1781 sec | Step  1553	loss: 1.324 	accuracy: 0.578
#
# epoch 9:
#
# 1497 sec | Step  6214	loss: 1.234 	accuracy: 0.602
# 1782 sec | Step  1553	loss: 1.291 	accuracy: 0.585
#
# epoch 10:
#
# 1497 sec | Step  6214	loss: 1.192 	accuracy: 0.612
# 1782 sec | Step  1553	loss: 1.265 	accuracy: 0.590
#
# epoch 11:
#
# 1497 sec | Step  6214	loss: 1.158 	accuracy: 0.620
# 1782 sec | Step  1553	loss: 1.242 	accuracy: 0.598
#
# epoch 12:
#
# 1497 sec | Step  6214	loss: 1.129 	accuracy: 0.628
# 1782 sec | Step  1553	loss: 1.234 	accuracy: 0.599
#
# epoch 13:
#
# 1497 sec | Step  6214	loss: 1.105 	accuracy: 0.634
# 1783 sec | Step  1553	loss: 1.214 	accuracy: 0.605
#
# epoch 14:
#
# 1498 sec | Step  6214	loss: 1.084 	accuracy: 0.640
# 1783 sec | Step  1553	loss: 1.207 	accuracy: 0.603
#
# epoch 15:
#
# 1498 sec | Step  6214	loss: 1.066 	accuracy: 0.644
# 1783 sec | Step  1553	loss: 1.199 	accuracy: 0.608
#
# epoch 16:
#
# 1498 sec | Step  6214	loss: 1.050 	accuracy: 0.649
# 1783 sec | Step  1553	loss: 1.191 	accuracy: 0.607
#
# epoch 17:
#
# 1498 sec | Step  6214	loss: 1.035 	accuracy: 0.653
# 1784 sec | Step  1553	loss: 1.183 	accuracy: 0.610
#
# epoch 18:
#
# 1498 sec | Step  6214	loss: 1.022 	accuracy: 0.656
# 1784 sec | Step  1553	loss: 1.179 	accuracy: 0.613
#
# epoch 19:
#
# 1498 sec | Step  6214	loss: 1.010 	accuracy: 0.660
# 1783 sec | Step  1553	loss: 1.175 	accuracy: 0.613
#
# epoch 20:
#
# 1498 sec | Step  6214	loss: 0.999 	accuracy: 0.663
# 1784 sec | Step  1553	loss: 1.170 	accuracy: 0.614
#
# epoch 21:
#
# 1499 sec | Step  6214	loss: 0.989 	accuracy: 0.666
# 1784 sec | Step  1553	loss: 1.166 	accuracy: 0.615
#
# epoch 22:
#
# 1499 sec | Step  6214	loss: 0.980 	accuracy: 0.668
# 1784 sec | Step  1553	loss: 1.165 	accuracy: 0.616
#
# epoch 23:
#
# 1499 sec | Step  6214	loss: 0.971 	accuracy: 0.671
# 1784 sec | Step  1553	loss: 1.162 	accuracy: 0.616
#
# epoch 24:
#
# 1499 sec | Step  6214	loss: 0.963 	accuracy: 0.673
# 1784 sec | Step  1553	loss: 1.161 	accuracy: 0.615
#
# epoch 25:
#
# 1500 sec | Step  6214	loss: 0.955 	accuracy: 0.675
# 1785 sec | Step  1553	loss: 1.159 	accuracy: 0.617
#
# epoch 26:
#
# 1501 sec | Step  6214	loss: 0.949 	accuracy: 0.677
# 1786 sec | Step  1553	loss: 1.159 	accuracy: 0.618
#
# epoch 27:
#
# 1500 sec | Step  6214	loss: 0.942 	accuracy: 0.679
# 1785 sec | Step  1553	loss: 1.157 	accuracy: 0.617
#
# epoch 28:
#
# 1501 sec | Step  6214	loss: 0.936 	accuracy: 0.681
# 1787 sec | Step  1553	loss: 1.158 	accuracy: 0.617
#
# epoch 29:
#
# 1502 sec | Step  6214	loss: 0.930 	accuracy: 0.683
# 1787 sec | Step  1553	loss: 1.158 	accuracy: 0.617
#
# epoch 30:
#
# 1503 sec | Step  6214	loss: 0.924 	accuracy: 0.684
# 1788 sec | Step  1553	loss: 1.157 	accuracy: 0.618

# %% [markdown]
# ## Translator

# %%
encoder.load_weights('./Checkpoints/RNN/Encoder/29.h5')
decoder.load_weights('./Checkpoints/RNN/Decoder/29.h5')

# %%
class GreedyTranslator(tf.Module):
    def __init__(self, encoder, decoder, fa_tokenizer, *, max_length=50, return_attention_weights=False):
        super(GreedyTranslator, self).__init__()

        self.encoder = encoder
        self.decoder = decoder
        self.fa_tokenizer = fa_tokenizer
        self.max_length = max_length
        self.start_token = fa_tokenizer.cls_token_id
        self.end_token = fa_tokenizer.sep_token_id
        self.pad_token = fa_tokenizer.pad_token_id
        self.return_attention_weights = return_attention_weights

    @tf.function(input_signature=[tf.TensorSpec(shape=(None, None), dtype=tf.int32)])
    def __call__(self, tokenized_sentence):
        batch_size = tf.shape(tokenized_sentence)[0]
        seqs, (h, bh) = encoder(tokenized)
        s_prev = tf.concat([h, bh], axis=-1)
        
        dec_inp_arr = tf.TensorArray(dtype=tf.int32, size=0, dynamic_size=True)
        dec_inp_arr = dec_inp_arr.write(0, tf.fill([batch_size], self.start_token))
        not_finished = tf.ones((batch_size,), tf.float32)
        attention_weights_arr = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
        
        for i in tf.range(self.max_length):
            dec_inp = tf.transpose(dec_inp_arr.stack())
            dec_inp = tf.expand_dims(dec_inp[:, -1], axis=-1)
            output, s_prev, attention_weights = decoder(dec_inp, seqs, s_prev, training=False)
            attention_weights_arr = attention_weights_arr.write(i, attention_weights[0, :, 0])
            output = tf.argmax(output, axis=-1)
            output = tf.cast(output, tf.float32)
            not_seen_end = tf.cast(tf.logical_not(tf.equal(output, self.end_token)), tf.float32)
            not_finished = not_seen_end * not_finished
            output = output * not_finished + (1 - not_finished) * self.pad_token

            output = tf.cast(output, tf.int32)
            dec_inp_arr = dec_inp_arr.write(i + 1, output[:])
        
            if tf.reduce_sum(not_finished) == 0:
                break

        outputs = tf.transpose(dec_inp_arr.stack())
        decoder_input_array = dec_inp_arr.close()

        if self.return_attention_weights:
            attentions = attention_weights_arr.stack()
            attention_weights_arr = attention_weights_arr.close()
            return outputs, attentions

        return outputs

# %%
from bidi.algorithm import get_display
import arabic_reshaper

greedyTranslator = GreedyTranslator(encoder, decoder, fa_tokenizer, max_length=100, return_attention_weights=True)

sentence = 'The bank is by the river bank.'
tokenized = en_tokenizer.encode(sentence, add_special_tokens=True)
tokenized = tf.expand_dims(tokenized, axis=0)
result, attention_scores = greedyTranslator(tokenized)
result = result.numpy()[0, 1:]

x_tick_labels = [en_tokenizer.decode([i]) for i in tokenized[0]]
y_tick_labels = [get_display(arabic_reshaper.reshape(fa_tokenizer.decode([i]))) for i in result]

fig = plt.figure(figsize=(5, 5))
ax = plt.subplot(111)
ax.matshow(attention_scores[:, :])
ax.set_xticks(range(len(x_tick_labels)))
ax.set_yticks(range(len(y_tick_labels)));
ax.set_xticklabels(x_tick_labels, rotation=90);
ax.set_yticklabels(y_tick_labels);

fig.savefig('./figures/RNN/attention_weights3.png', dpi=320)
