# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '20'

import numpy as np
import pandas as pd
import re
import csv
from parsivar import Normalizer
import tensorflow_text as tf_text

# %%
def count_english_words(row):
    if row is None:
        return 10
    words = row.split(' ')
    cnt = 0
    for word in words:
        if re.match('[a-zA-z]+', word):
            cnt += 1
            
    return cnt

# %%
def read_data_from_dir(directory='./'):
    files = os.listdir(directory)
    data = []
    for file in files:
        if 'done' not in file: 
            continue
        with open(file, 'r') as txtfile:
            data.append(txtfile.read())

    data = '\n'.join(data).split('\n')
    data = [x.split('\t')[:2] for x in data]
    df = pd.DataFrame(data, columns=['Source', 'Target'])
    return df

# %%
MAX_SOURCE_LEN = 30

fa_normalizer = Normalizer()

data = read_data_from_dir()
data['Source'] = data['Source'].str.strip().replace('...', ' ')
data['Target'] = data['Target'].str.strip().replace('...', ' ')
data['Target'] = data['Target'].map(lambda x: fa_normalizer.normalize(x) if x is not None else None)
data = data[data['Target'].map(lambda x: count_english_words(x) == 0)]
data['Target'] = data['Target'].map(lambda x: re.sub('\u200c', ' ', x))
data = data[data['Source'].map(lambda x: len(x.split(' ')) <= MAX_SOURCE_LEN)]
data = data.drop_duplicates(keep='first')
print(len(data))
data = data.dropna()
data
# Out:
# 297378
#                                                    Source  \
# 0          the current king is only kim myung 's puppet .
# 1              how could he ask for consul jang 's help ,
# 2       when he must know what happened between kim my...
# 3       but he said in the letter that his life was in...
# 4       he would seek help anywhere if his life were i...
# ...                                                   ...
# 553230           they heard the cause of the disturbance.
# 553502            Madame de Saint Meran two months since;
# 553581               Have you, then, power against death?
# 553626           Have you something to tell me? asked he.
# 553689   Then you have thought that Barrois was poisoned?
#
#                                                    Target
# 0       پادشاه فعلی فقط عروسک خیمه شب بازی کیم میونگ ا...
# 1              چگونه می توانست از کنسول جانگ کمک بخواهد ،
# 2       وقتی او باید بداند بین کیم میونگ و کنسول جانگ ...
# 3               اما در نامه گفته است که جانش در خطر است .
# 4              اگر جانش در خطر بود از هر جا کمک می گرفت .
# ...                                                   ...
# 553230                             علت اغتشاش را شنیدند .
# 553502              مادام دو سنت مران دو ماه از آن زمان ;
# 553581                  پس آیا قدرتی در برابر مرگ دارید ؟
# 553626         چیزی دارید که به من بگویید ؟ از او پرسید .
# 553689           پس فکر کرده اید که باروآ مسموم شده است ؟
#
# [297378 rows x 2 columns]

# %%
data.to_csv('combined.txt', sep='\t', header=False, index=False, encoding='utf-8')
